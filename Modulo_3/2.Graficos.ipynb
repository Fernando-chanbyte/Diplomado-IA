# %% [markdown]
# # Graficos en python

# %%
#!pip uninstall matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = [0,2,4,6,8,10]

y = [89,67,45,65,23,67]

plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.title('ventas')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(x,y)
plt.title('ventas')
plt.xlabel('Dias')
plt.ylabel('numero de ventas')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
experiencia = [1,3,5,7]
salario_data_scientists = [3434, 6436,4656,8999]
salario_ing_software = [5655,5858,5555,6565]

# %%
plt.plot(experiencia, salario_data_scientists)
plt.plot(salario_ing_software)
plt.title('salarios')
plt.xlabel('ventas')
plt.ylabel('salario')
plt.legend(['Data_scientist', 'data_softwwer'])
plt.show()

# %%
plt.plot(experiencia, salario_data_scientists, color = 'r', label = 'd')
plt.plot(salario_ing_software)
plt.title('salarios')
plt.xlabel('ventas')
plt.ylabel('salario')
plt.legend(['Data_scientist', 'data_softwwer'])
plt.show()

# %%
x = ['A', 'B', 'C', 'D']
y = [3, 8, 1, 10]
plt.show()

# %%
import numpy as np

# %%
x = np.random.rand(100)
y = np.random.rand(100)

# %%
plt.scatter(x,y)
plt.title('Grafico de dispersion')
plt.show()

# %%
datos = np.random.randn(10000)

plt.hist(datos,bins=100)
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.show()

# %%
datos = [np.random.normal(0,std,100) for std in range(1,4)]
plt.boxplot(datos,vert=True)
plt.show()

# %%
import pandas as pd

data_range = pd.date_range(start='2023-01-01',end='2023-12-31',freq='D')
precios = np.cumsum(np.random.randn(len(data_range))) + 100

# %%
data = pd.DataFrame({'Date':data_range,'precios': precios})
data.head()
# Out:
#         Date     precios
# 0 2023-01-01  100.113689
# 1 2023-01-02   99.328141
# 2 2023-01-03   98.721273
# 3 2023-01-04   98.782344
# 4 2023-01-05   98.754397

# %%
plt.plot(data['Date'],data['precios'], label='Precio')
plt.show()

# %%
x = np.linspace(0,10,100)
y1 = np.sin(x)
y2 = np.cos(x)

categorias = ['A','B','C','D']
valores = [5,7,3,8]

spx = np.random.rand(100)
spy = np.random.rand(100)

val = [np.random.normal (0,std,100) for std in range (1,3)]

# %%
fig, axs = plt.subplots(2,2, figsize = (15,10))

axs[0,0].plot(x,y1, label = 'Seno')
axs[0,0].plot(x,y2,label= 'Coseno')
axs[0,0].set_title('Gráfico de lineas')
axs[0,0].legend(loc='upper right')
axs[0,0].grid(True)

axs[0,1].bar(categorias, valores)
axs[0,1].set_title('Gráfico de barras')

axs[1,0].scatter(spx,spy, color ="green")
axs[1,0].set_title('Grafico de dispersion')

axs[1,1].boxplot(val)
axs[1,1].set_title('Grafica de cajas y bigotes')
# Out:
# Text(0.5, 1.0, 'Grafica de cajas y bigotes')
