# %% [markdown]
# # Análisis exploratorio de una base de datos descargada de la plataforma kaggle

# %%
import pandas as pd

# %%
#lectura de los Datos

df = pd.read_csv('dataR1.csv')
df
# Out:
#       Random   Average  of chlorophyll in the plant (ACHP)  \
# 0         R1                                     34.533468
# 1         R1                                     34.489028
# 2         R2                                     33.100405
# 3         R1                                     34.498319
# 4         R3                                     36.297008
# ...      ...                                           ...
# 29995     R3                                     46.400873
# 29996     R3                                     46.395047
# 29997     R2                                     32.707725
# 29998     R1                                     38.624079
# 29999     R3                                     46.409177
#
#         Plant height rate (PHR)  \
# 0                     54.566983
# 1                     54.567692
# 2                     67.067344
# 3                     54.559049
# 4                     45.588894
# ...                         ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(7)
# Out:
#   Random   Average  of chlorophyll in the plant (ACHP)  \
# 0     R1                                     34.533468
# 1     R1                                     34.489028
# 2     R2                                     33.100405
# 3     R1                                     34.498319
# 4     R3                                     36.297008
# 5     R3                                     36.287722
# 6     R1                                     34.498869
#
#     Plant height rate (PHR)  \
# 0                 54.566983
# 1                 54.567692
# 2                 67.067344
# 3                 54.559049
# 4                 45.588894
# 5                 45.598585
# 6                 54.556247
#
#    Average wet weight of the growth vegetative (AWWGV)  \
# 0                                           1.147449
# 1                                           1.149530
# 2                                           1.104647
# 3                                           1.137759
# ...

# %%
df.tail(5)
# Out:
#       Random   Average  of chlorophyll in the plant (ACHP)  \
# 29995     R3                                     46.400873
# 29996     R3                                     46.395047
# 29997     R2                                     32.707725
# 29998     R1                                     38.624079
# 29999     R3                                     46.409177
#
#         Plant height rate (PHR)  \
# 29995                 50.830830
# 29996                 50.838058
# 29997                 37.065408
# 29998                 37.876323
# 29999                 50.841213
#
#        Average wet weight of the growth vegetative (AWWGV)  \
# 29995                                           0.883813
# 29996                                           0.900390
# 29997                                           0.909055
# 29998                                           1.077557
# 29999                                           0.871211
#
#        Average leaf area of the plant (ALAP)  \
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.head(3)
# Out:
#   Random   Average  of chlorophyll in the plant (ACHP)  \
# 0     R1                                     34.533468
# 1     R1                                     34.489028
# 2     R2                                     33.100405
#
#     Plant height rate (PHR)  \
# 0                 54.566983
# 1                 54.567692
# 2                 67.067344
#
#    Average wet weight of the growth vegetative (AWWGV)  \
# 0                                           1.147449
# 1                                           1.149530
# 2                                           1.104647
#
#    Average leaf area of the plant (ALAP)  \
# 0                            1284.229549
# 1                            1284.247744
# 2                            1009.208996
#
#    Average number of plant leaves (ANPL)  Average root diameter (ARD)  \
# 0                               4.999713                    16.274918
# 1                               5.024259                    16.269452
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 14 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Random                                                   30000 non-null  object
#  1    Average  of chlorophyll in the plant (ACHP)             30000 non-null  float64
#  2    Plant height rate (PHR)                                 30000 non-null  float64
#  3   Average wet weight of the growth vegetative (AWWGV)      30000 non-null  float64
#  4   Average leaf area of the plant (ALAP)                    30000 non-null  float64
#  5   Average number of plant leaves (ANPL)                    30000 non-null  float64
#  6   Average root diameter (ARD)                              30000 non-null  float64
#  7    Average dry weight of the root (ADWR)                   30000 non-null  float64
# ...

# %%
df['Random'].unique()
# Out:
# array(['R1', 'R2', 'R3'], dtype=object)

# %%
df['Class'].unique()
# Out:
# array(['SA', 'SB', 'SC', 'TA', 'TB', 'TC'], dtype=object)

# %%
df['Average wet weight of the growth vegetative (AWWGV)'].unique()
# Out:
# array([1.14744902, 1.1495298 , 1.10464721, ..., 0.90905483, 1.07755726,
#        0.87121062])

# %%
df.nunique()
# Out:
# Random                                                         3
#  Average  of chlorophyll in the plant (ACHP)               30000
#  Plant height rate (PHR)                                   30000
# Average wet weight of the growth vegetative (AWWGV)        30000
# Average leaf area of the plant (ALAP)                      30000
# Average number of plant leaves (ANPL)                      30000
# Average root diameter (ARD)                                30000
#  Average dry weight of the root (ADWR)                     30000
#  Percentage of dry matter for vegetative growth (PDMVG)    30000
# Average root length (ARL)                                  30000
# Average wet weight of the root (AWWR)                      30000
#  Average dry weight of vegetative plants (ADWV)            30000
# Percentage of dry matter for root growth (PDMRG)           30000
# Class                                                          6
# dtype: int64

# %%
#df.columns.to_list() #me genera una lista de los nombres de las columnas en la tabla

for name in df.columns.to_list():
    print(f'La columna: {name} contiene los elementos {df[name].unique()}')
# Out:
# La columna: Random contiene los elementos ['R1' 'R2' 'R3']
# La columna:  Average  of chlorophyll in the plant (ACHP) contiene los elementos [34.53346786 34.48902831 33.10040473 ... 32.70772487 38.6240785
#  46.40917724]
# La columna:  Plant height rate (PHR) contiene los elementos [54.56698291 54.56769212 67.06734371 ... 37.06540776 37.87632299
#  50.84121303]
# La columna: Average wet weight of the growth vegetative (AWWGV) contiene los elementos [1.14744902 1.1495298  1.10464721 ... 0.90905483 1.07755726 0.87121062]
# La columna: Average leaf area of the plant (ALAP) contiene los elementos [1284.22954908 1284.24774388 1009.20899584 ...  857.84938026  948.66342405
#   744.29837955]
# La columna: Average number of plant leaves (ANPL) contiene los elementos [4.99971308 5.02425915 5.00765198 ... 2.99271194 4.00228364 4.02051656]
# La columna: Average root diameter (ARD) contiene los elementos [16.27491791 16.26945189 15.98075994 ... 18.20098421 15.733098
#  17.81372278]
# ...

# %%
#Eliminar columnas que no brindan informacion
valores_unicos_n = df.nunique()

columnas_sn_info = valores_unicos_n[valores_unicos_n == 1].index.to_list()
columnas_sn_info
# Out:
# []

# %%
df_clean = df.drop(columnas_sn_info,axis=1)

# %%
#df_clean = df_clean.drop('JobSatisfaction', axis=1) #ejemplo de eliminacion de una columna en especifico

# %%
df.head(3)
# Out:
#   Random   Average  of chlorophyll in the plant (ACHP)  \
# 0     R1                                     34.533468
# 1     R1                                     34.489028
# 2     R2                                     33.100405
#
#     Plant height rate (PHR)  \
# 0                 54.566983
# 1                 54.567692
# 2                 67.067344
#
#    Average wet weight of the growth vegetative (AWWGV)  \
# 0                                           1.147449
# 1                                           1.149530
# 2                                           1.104647
#
#    Average leaf area of the plant (ALAP)  \
# 0                            1284.229549
# 1                            1284.247744
# 2                            1009.208996
#
#    Average number of plant leaves (ANPL)  Average root diameter (ARD)  \
# 0                               4.999713                    16.274918
# 1                               5.024259                    16.269452
# ...

# %%
df_clean.describe()
# Out:
#         Average  of chlorophyll in the plant (ACHP)   Plant height rate (PHR)  \
# count                                  30000.000000              30000.000000
# mean                                      38.060575                 59.020331
# std                                        4.441682                 11.985213
# min                                       32.664004                 37.020398
# 25%                                       34.399604                 51.059436
# 50%                                       36.575753                 55.912058
# 75%                                       42.300836                 67.069465
# max                                       46.431668                 77.040610
#
#        Average wet weight of the growth vegetative (AWWGV)  \
# count                                       30000.000000
# mean                                            1.247257
# std                                             0.245989
# ...

# %% [markdown]
# Plantas con promedio de clorofila > 40

# %%
clorofila_promedio =df_clean[(df_clean[' Average  of chlorophyll in the plant (ACHP)'] >= 46)]

# %%
clorofila_promedio.describe()
# Out:
#         Average  of chlorophyll in the plant (ACHP)   Plant height rate (PHR)  \
# count                                   1684.000000               1684.000000
# mean                                      46.399881                 50.840212
# std                                        0.010097                  0.010334
# min                                       46.361027                 50.798257
# 25%                                       46.392865                 50.833168
# 50%                                       46.399779                 50.840266
# 75%                                       46.406906                 50.847152
# max                                       46.431668                 50.869418
#
#        Average wet weight of the growth vegetative (AWWGV)  \
# count                                        1684.000000
# mean                                            0.880867
# std                                             0.009828
# ...

# %%
Relacion_clorofila_foliar_raiz = df_clean[(df_clean[' Average  of chlorophyll in the plant (ACHP)'] >= 20) &
                                          (df_clean['Average leaf area of the plant (ALAP)'] >= 1000) &
                                          (df_clean['Average root length (ARL)'] >= 20)]

# %%
Relacion_clorofila_foliar_raiz.describe()
# Out:
#         Average  of chlorophyll in the plant (ACHP)   Plant height rate (PHR)  \
# count                                   8285.000000               8285.000000
# mean                                      34.771541                 72.115742
# std                                        1.205632                  4.407836
# min                                       33.066194                 66.412321
# 25%                                       34.193178                 67.063920
# 50%                                       34.398843                 74.900035
# 75%                                       35.606619                 75.017194
# max                                       36.631543                 77.040610
#
#        Average wet weight of the growth vegetative (AWWGV)  \
# count                                        8285.000000
# mean                                            1.300033
# std                                             0.175260
# ...

# %% [markdown]
# conclusion:  la media del promedio de clorofila que presenta una planta cuya clorofila es mayor a 20, es de 34.77
#             la longitud promedio de la raiz es de 21.47 de las 8285 plantas cuya longitud de raiz es mayor a 20
#             el area foliar de las plantas mayores a 1000 en promedio es de 1339.21
