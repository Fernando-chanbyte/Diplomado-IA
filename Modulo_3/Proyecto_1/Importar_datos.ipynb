# %%
import pandas as pd

# %%
#lectura de los Datos

df = pd.read_csv('Human_Resources.csv')
df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# 1              1  ...                         4             80
#
#   StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                0                  8                      0                1
# 1                1                 10                      3                3
#
#   YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0              6                   4                       0
# ...

# %%
df.tail(2)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 1468                2              9                   6
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df.head(3)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female          94
# 1              1             2.0                        3    Male          61
# 2              1             4.0                        4    Male          92
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1469 non-null   float64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1469 non-null   object
# ...

# %%
df['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', nan, 'Human Resources'],
#       dtype=object)

# %%
df['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', nan, 'Human Resources'],
#       dtype=object)

# %%
df['Age'].unique()
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60], dtype=int64)

# %%
df['Over18'].unique()
# Out:
# array(['Y'], dtype=object)

# %%
df['OverTime'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['RelationshipSatisfaction'].unique() #identificacion de valores unicos
# Out:
# array([1, 4, 2, 3], dtype=int64)

# %%
df.nunique()
# Out:
# Age                           43
# MonthlyIncome               1346
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1469
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyRate                 1425
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
#df.columns.to_list() #me genera una lista de los nombres de las columnas en la tabla

for name in df.columns.to_list():
    print(f'La columna: {name} contiene los elementos {df[name].unique()}')
# Out:
# La columna: Age contiene los elementos [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# La columna: MonthlyIncome contiene los elementos [5993.   nan 2090. ... 9991. 5390. 4404.]
# La columna: Attrition contiene los elementos ['Yes' 'No']
# La columna: BusinessTravel contiene los elementos ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# La columna: DailyRate contiene los elementos [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
# ...

# %%
#Eliminar columnas que no brindan informacion
valores_unicos_n = df.nunique()

columnas_sn_info = valores_unicos_n[valores_unicos_n == 1].index.to_list()
columnas_sn_info
# Out:
# ['EmployeeCount', 'Over18', 'StandardHours']

# %%
df_clean = df.drop(columnas_sn_info,axis=1)

# %%
#df_clean = df_clean.drop('JobSatisfaction', axis=1) #ejemplo de eliminacion de una columna en especifico

# %%
df.head(3)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female          94
# 1              1             2.0                        3    Male          61
# 2              1             4.0                        4    Male          92
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# ...

# %%
df_clean.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810    6505.155419   802.485714          9.192517     2.912925
# std       9.135373    4711.297846   403.509100          8.106864     1.024165
# min      18.000000    1009.000000   102.000000          1.000000     1.000000
# 25%      30.000000    2911.000000   465.000000          2.000000     2.000000
# 50%      36.000000    4908.000000   802.000000          7.000000     3.000000
# 75%      43.000000    8378.000000  1157.000000         14.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1469.000000              1470.000000  1470.000000     1470.000000
# mean      1025.556161                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# #personas que siguen trabajndo en la empresa

# %%
siguen_trabajando = df_clean[df_clean['Attrition'] == 'No']
renunciaron = df_clean[df_clean['Attrition'] == 'Yes']

# %%
df_clean.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810    6505.155419   802.485714          9.192517     2.912925
# std       9.135373    4711.297846   403.509100          8.106864     1.024165
# min      18.000000    1009.000000   102.000000          1.000000     1.000000
# 25%      30.000000    2911.000000   465.000000          2.000000     2.000000
# 50%      36.000000    4908.000000   802.000000          7.000000     3.000000
# 75%      43.000000    8378.000000  1157.000000         14.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1469.000000              1470.000000  1470.000000     1470.000000
# mean      1025.556161                 2.721769    65.891156        2.729932
# ...

# %%
siguen_trabajando['Attrition'].unique()
# Out:
# array(['No'], dtype=object)

# %%
renunciaron.describe()
# Out:
#               Age  MonthlyIncome    DailyRate  DistanceFromHome   Education  \
# count  237.000000     236.000000   237.000000        237.000000  237.000000
# mean    33.607595    4771.588983   750.362869         10.632911    2.839662
# std      9.689350    3640.097444   401.899519          8.452525    1.008244
# min     18.000000    1009.000000   103.000000          1.000000    1.000000
# 25%     28.000000    2371.500000   408.000000          3.000000    2.000000
# 50%     32.000000    3187.000000   699.000000          9.000000    3.000000
# 75%     39.000000    5850.000000  1092.000000         17.000000    4.000000
# max     58.000000   19859.000000  1496.000000         29.000000    5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      237.000000               237.000000  237.000000      237.000000
# mean      1010.345992                 2.464135   65.573840        2.518987
# ...

# %%
siguen_trabajando.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1233.000000    1231.000000  1233.000000       1233.000000  1233.000000
# mean     37.561233    6837.504468   812.504461          8.915653     2.927007
# std       8.888360    4820.415800   403.208379          8.012633     1.027002
# min      18.000000    1051.000000   102.000000          1.000000     1.000000
# 25%      31.000000    3211.500000   477.000000          2.000000     2.000000
# 50%      36.000000    5206.000000   817.000000          7.000000     3.000000
# 75%      43.000000    8835.500000  1176.000000         13.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1232.000000              1233.000000  1233.000000     1233.000000
# mean      1028.482143                 2.771290    65.952149        2.770479
# ...

# %%
personas_sueldo_bien = siguen_trabajando[(siguen_trabajando['MonthlyIncome'] > 10000) & (siguen_trabajando['DistanceFromHome'] > 8)]

# %%
personas_sueldo_bien.describe()
# Out:
#              Age  MonthlyIncome    DailyRate  DistanceFromHome  Education  \
# count  93.000000      93.000000    93.000000         93.000000  93.000000
# mean   45.225806   14717.795699   809.290323         18.204301   3.150538
# std     7.348660    3190.457213   421.171750          6.940053   0.988480
# min    30.000000   10266.000000   102.000000          9.000000   1.000000
# 25%    40.000000   11510.000000   458.000000         11.000000   3.000000
# 50%    45.000000   13973.000000   829.000000         18.000000   3.000000
# 75%    50.000000   17181.000000  1176.000000         25.000000   4.000000
# max    60.000000   19926.000000  1499.000000         29.000000   5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count       93.000000                93.000000   93.000000       93.000000
# mean      1107.795699                 2.838710   70.053763        2.709677
# std        555.774617                 1.066183   18.865292        0.668884
# ...

# %%
personas_sueldo_bien = siguen_trabajando[(siguen_trabajando['MonthlyIncome'] > 10000) | (siguen_trabajando['DistanceFromHome'] > 8)]

# %%
personas_sueldo_bien.describe()
# Out:
#               Age  MonthlyIncome    DailyRate  DistanceFromHome   Education  \
# count  656.000000     656.000000   656.000000        656.000000  656.000000
# mean    39.425305    8735.211890   812.059451         13.629573    2.964939
# std      9.308483    5672.922517   406.162459          8.247043    1.011532
# min     18.000000    1052.000000   102.000000          1.000000    1.000000
# 25%     33.000000    4013.250000   469.000000          9.000000    2.000000
# 50%     39.000000    6558.000000   803.000000         11.000000    3.000000
# 75%     46.000000   13325.250000  1179.250000         20.000000    4.000000
# max     60.000000   19999.000000  1499.000000         29.000000    5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      656.000000               656.000000  656.000000      656.000000
# mean      1032.387195                 2.760671   66.393293        2.769817
# ...

# %%
personas_sueldo_bien[personas_sueldo_bien['JobRole'] == 'Research Director'].describe()
# Out:
#              Age  MonthlyIncome    DailyRate  DistanceFromHome  Education  \
# count  78.000000      78.000000    78.000000         78.000000  78.000000
# mean   43.858974   15947.346154   801.923077          8.474359   3.115385
# std     7.857041    2810.948501   399.052735          7.589679   1.080894
# min    27.000000   11031.000000   102.000000          1.000000   1.000000
# 25%    38.000000   13472.750000   449.750000          2.000000   2.250000
# 50%    44.500000   16417.500000   811.500000          7.000000   3.000000
# 75%    50.000000   18707.750000  1123.250000         11.750000   4.000000
# max    58.000000   19973.000000  1482.000000         28.000000   5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count       78.000000                78.000000   78.000000       78.000000
# mean      1003.846154                 2.487179   64.371795        2.769231
# std        592.927561                 1.159306   19.706357        0.701077
# ...

# %% [markdown]
# #Tratamiento de datos faltantes

# %%
df_clean.isnull()
# Out:
#         Age  MonthlyIncome  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False          False      False           False      False       False
# 1     False           True      False           False      False       False
# 2     False          False      False           False      False       False
# 3     False          False      False           False      False       False
# 4     False          False      False           False      False       False
# ...     ...            ...        ...             ...        ...         ...
# 1465  False          False      False           False      False       False
# 1466  False          False      False           False      False       False
# 1467  False          False      False           False      False       False
# 1468  False          False      False           False      False       False
# 1469  False          False      False           False      False       False
#
# ...

# %%
df_clean.isnull().sum()
# Out:
# Age                         0
# MonthlyIncome               3
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyRate                 2
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# ...

# %%
#contamos cuantos valores nulos tenemos por cada variable 

valores_nulos = df_clean.isnull().sum()
valores_nulos
# Out:
# Age                         0
# MonthlyIncome               3
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyRate                 2
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# ...

# %%
len(df_clean) # numero de filas
# Out:
# 1470

# %%
porcentaje = (valores_nulos / len(df_clean)) * 100
porcentaje
# Out:
# Age                         0.000000
# MonthlyIncome               0.204082
# Attrition                   0.000000
# BusinessTravel              0.000000
# DailyRate                   0.000000
# Department                  0.068027
# DistanceFromHome            0.000000
# Education                   0.000000
# EducationField              0.068027
# EmployeeNumber              0.068027
# EnvironmentSatisfaction     0.000000
# Gender                      0.068027
# HourlyRate                  0.000000
# JobInvolvement              0.000000
# JobLevel                    0.000000
# JobRole                     0.068027
# JobSatisfaction             0.000000
# MaritalStatus               0.068027
# MonthlyRate                 0.136054
# NumCompaniesWorked          0.000000
# OverTime                    0.000000
# PercentSalaryHike           0.068027
# PerformanceRating           0.068027
# RelationshipSatisfaction    0.000000
# StockOptionLevel            0.000000
# ...

# %%
#df_clean_sn_na = df_clean.dropna(axis=0)
#df_clean_sn_na = df_clean.fillna(0) #les pone ceros a los valores NA
#df_clean['MonthlyIncome'] = df_clean['MonthlyIncome'].fillna(df_clean['MonthlyIncome'].median())

# %%
#len(df_clean_sn_na)

# %%
#df_clean_sn_na.isnull().sum()

# %%
#%pip install -U scikit-learn

# %%
from sklearn.impute import SimpleImputer

impute_numeric = SimpleImputer(strategy='mean')

impute_columns = df_clean.select_dtypes(include='number').columns
df_clean[numeric_columns] = impute_numeric.fit_transform(df_clean[numeric_columns])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 6
#       3 impute_numeric = SimpleImputer(strategy='mean')
#       5 impute_columns = df_clean.select_dtypes(include='number').columns
# ----> 6 df_clean[numeric_columns] = impute_numeric.fit_transform(df_clean[numeric_columns])
#
# NameError: name 'numeric_columns' is not defined

# %%
df_clean[numeric_columns] = impute_numeric.fit_transform(df_clean[numeric_columns])

# %%
impute_numeric = SimpleImputer(strategy='mean')

categorical_columns = df_clean.select_dtypes(include='object').columns
df_clean[categorical_columns] = impute_categorico.fit_transform(df_clean[categorical_columns])

# %% [markdown]
# # Tratar con datos nominales y ordinales

# %%
for name in df_clean.columns.to_list():
    print(f'{name}: {df_clean[name].unique()}')
    print('\n')
# Out:
# Age: [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
#
#
# MonthlyIncome: [5993.   nan 2090. ... 9991. 5390. 4404.]
#
#
# Attrition: [nan]
#
#
# BusinessTravel: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
#
#
# DailyRate: [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
#   489  807  827  871  665 1040 1420  240 1280  534 1456  658  142 1127
#  1031 1189 1354 1467  922  394 1312  750  441  684  249  841  147  528
# ...

# %%
# Variables Ordinales

Attrition_labels = {'Yes':1 , 'No':0}
df_clean['Attrition'] = df_clean['Attrition'].map(Attrition_labels)

# %%
df_clean
# Out:
#       Age  MonthlyIncome  Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0        NaN      Travel_Rarely       1102
# 1      49            NaN        NaN  Travel_Frequently        279
# 2      37         2090.0        NaN      Travel_Rarely       1373
# 3      33         2909.0        NaN  Travel_Frequently       1392
# 4      27         3468.0        NaN      Travel_Rarely        591
# ...   ...            ...        ...                ...        ...
# 1465   36         2571.0        NaN  Travel_Frequently        884
# 1466   39         9991.0        NaN      Travel_Rarely        613
# 1467   27         6142.0        NaN      Travel_Rarely        155
# 1468   49         5390.0        NaN  Travel_Frequently       1023
# 1469   34         4404.0        NaN      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
#variables Nominales 
df_clean = pd.get_dummies(df_clean, columns=['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime'])

# %%
df_clean
# Out:
#       Age  MonthlyIncome  Attrition  DailyRate  DistanceFromHome  Education  \
# 0      41         5993.0        NaN       1102                 1          2
# 1      49            NaN        NaN        279                 8          1
# 2      37         2090.0        NaN       1373                 2          2
# 3      33         2909.0        NaN       1392                 3          4
# 4      27         3468.0        NaN        591                 2          1
# ...   ...            ...        ...        ...               ...        ...
# 1465   36         2571.0        NaN        884                23          2
# 1466   39         9991.0        NaN        613                 6          1
# 1467   27         6142.0        NaN        155                 4          3
# 1468   49         5390.0        NaN       1023                 2          3
# 1469   34         4404.0        NaN        628                 8          3
#
# ...

# %%
df_clean.describe()
# Out:
#                Age  MonthlyIncome  Attrition    DailyRate  DistanceFromHome  \
# count  1470.000000    1467.000000        0.0  1470.000000       1470.000000
# mean     36.923810    6505.155419        NaN   802.485714          9.192517
# std       9.135373    4711.297846        NaN   403.509100          8.106864
# min      18.000000    1009.000000        NaN   102.000000          1.000000
# 25%      30.000000    2911.000000        NaN   465.000000          2.000000
# 50%      36.000000    4908.000000        NaN   802.000000          7.000000
# 75%      43.000000    8378.000000        NaN  1157.000000         14.000000
# max      60.000000   19999.000000        NaN  1499.000000         29.000000
#
#          Education  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count  1470.000000     1469.000000              1470.000000  1470.000000
# mean      2.912925     1025.556161                 2.721769    65.891156
# ...

# %%
df_clean.to_csv('Preproced.csv', index= False)

# %% [markdown]
# # Deteccion de valores atipicos

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
Q1 = df_clean['Age'].quantile(0.25)
Q3 = df_clean['Age'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 -1.5 * IQR

print(limite_inferior)

limite_superior =Q3 + 1.5 * IQR

print(limite_superior)
# Out:
# 10.5
# 62.5

# %% [markdown]
# ## Notas: simulacion de datos atipicos

# %%
df_test = df_clean.copy()

indices = np.random.choice(df_test.index, 2, replace = False)
df_test.loc[indices[0], 'Age'] += 3 * IQR
df_test.loc[indices[0], 'Age'] += 3 * IQR

# %%
df_test.boxplot(column= 'Age')
# Out:
# <Axes: >

# %%
Q1 = df_clean['Age'].quantile(0.25)
Q3 = df_clean['Age'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior

limite_inferior

limite_superior =Q3 + 1.5

# %% [markdown]
# # Ejercicio 3

# %% [markdown]
# Tomar 3 variables y determinar si existen datos atípicos

# %%
Q1 = df_clean['EmployeeNumber'].quantile(0.25)
Q3 = df_clean['EmployeeNumber'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 -1.5 * IQR

print(limite_inferior)

limite_superior =Q3 + 1.5 * IQR

print(limite_superior)
# Out:
# -1104.0
# 3152.0

# %%
df_clean.boxplot(column= 'EmployeeNumber')
# Out:
# <Axes: >

# %%
df_clean.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810    6505.155419   802.485714          9.192517     2.912925
# std       9.135373    4711.297846   403.509100          8.106864     1.024165
# min      18.000000    1009.000000   102.000000          1.000000     1.000000
# 25%      30.000000    2911.000000   465.000000          2.000000     2.000000
# 50%      36.000000    4908.000000   802.000000          7.000000     3.000000
# 75%      43.000000    8378.000000  1157.000000         14.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1469.000000              1470.000000  1470.000000     1470.000000
# mean      1025.556161                 2.721769    65.891156        2.729932
# ...

# %%
Q1 = df_clean['EmployeeNumber'].quantile(0.25)
Q3 = df_clean['EmployeeNumber'].quantile(0.75)

IQR = Q3 - Q1

limite_inferior = Q1 -1.5 * IQR

print(limite_inferior)

limite_superior =Q3 + 1.5 * IQR

print(limite_superior)

# %%
#plt.hist(df_clean['Age'], bins = 30)
#sns.distplot(x=df_clean['Age'])
#plt.show()

df_clean.hist(bins=30, figsize=(30,30))
plt.show()

# %%
# ITres, Bosques de aislamiento

# %%
from sklearn.ensemble import IsolationForest
forest = IsolationForest(contamination='auto').fit(df_clean[['Age']])
forest.predict(df_test[['Age']])

# %%
df_clean.shape
# Out:
# (1470, 32)

# %%
import seaborn as sns

correlaciones = df_clean.corr()

f,ax = plt.subplots(figsize = (30,30))

sns.heatmap(correlaciones, annot= True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 3
#       1 import seaborn as sns
# ----> 3 correlaciones = df_clean.corr()
#       5 f,ax = plt.subplots(figsize = (30,30))
#       7 sns.heatmap(correlaciones, annot= True)
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
sns.pairplot(df_clean, vars=['MonthlyIncome', 'Age'])
# Out:
# c:\Users\ferna\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ferna\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(df_clean, hue= 'Education', vars=['MonthlyIncome', 'Age'])
# Out:
# c:\Users\ferna\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ferna\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
